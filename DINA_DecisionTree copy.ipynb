# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## Data Spesies Tumbuhan dalam Genus yang sama
#
# | No | Kelas               | Diameter Buah (cm) | Berat Buah (gram) |
# | -- | ------------------- | ------------------ | ----------------- |
# | 1  | Cucumis sativus     | 4.2                | 500               |
# | 2  | Cucumis sativus     | 4.5                | 530               |
# | 3  | Cucumis sativus     | 4.0                | 480               |
# | 4  | Cucumis sativus     | 3.8                | 430               |
# | 5  | Cucumis sativus     | 4.3                | 510               |
# | 6  | Cucumis melo        | 16.0               | 1800              |
# | 7  | Cucumis melo        | 17.0               | 1900              |
# | 8  | Cucumis melo        | 15.0               | 1750              |
# | 9  | Cucumis melo        | 17.5               | 2000              |
# | 10 | Cucumis melo        | 14.0               | 1600              |
# | 11 | Cucumis metuliferus | 7.0                | 900               |
# | 12 | Cucumis metuliferus | 7.5                | 950               |
# | 13 | Cucumis metuliferus | 6.8                | 870               |
# | 14 | Cucumis metuliferus | 8.0                | 1000              |
# | 15 | Cucumis metuliferus | 7.2                | 920               |

# %% [markdown]
# # Analisis Data 3 Kelas: Cucumis Genus
#
# ## 1️⃣ Jumlah Data Berdasarkan Kelas
#
# Total data = **15**
#
# - **Cucumis sativus** = 5
# - **Cucumis melo** = 5
# - **Cucumis metuliferus** = 5
#
# ---
#
# ## 2️⃣ Fitur: Diameter Buah (cm)
#
# Urutan data berdasarkan diameter secara ascending:
#
# | No | Diameter Buah (cm) | Kelas               |
# |----|--------------------|---------------------|
# | 4  | 3.8                | Cucumis sativus     |
# | 3  | 4.0                | Cucumis sativus     |
# | 1  | 4.2                | Cucumis sativus     |
# | 5  | 4.3                | Cucumis sativus     |
# | 2  | 4.5                | Cucumis sativus     |
# | 11 | 6.8                | Cucumis metuliferus |
# | 15 | 7.0                | Cucumis metuliferus |
# | 16 | 7.2                | Cucumis metuliferus |
# | 12 | 7.5                | Cucumis metuliferus |
# | 14 | 8.0                | Cucumis metuliferus |
# | 13 | 14.0               | Cucumis melo        |
# | 9  | 15.0               | Cucumis melo        |
# | 10 | 15.5               | Cucumis melo        |
# | 6  | 16.0               | Cucumis melo        |
# | 7  | 17.0               | Cucumis melo        |
#
# ---
#
# ## 3️⃣ Threshold Split: 6.0 cm
#
# - **Group Left (≤ 6.0 cm)**: 5 data → *Cucumis sativus*
# - **Group Right (> 6.0 cm)**: 10 data → *Cucumis metuliferus* dan *Cucumis melo*
#
# ---
#
# ## 4️⃣ Entropy Awal
#
# Rumus:
#
# ```math
# Entropy(D) = - \sum p_i \log_2(p_i)

# %% [markdown]
# Baik! Sekarang kita akan menghitung ulang perhitungan manual *Information Gain* dan *Gini Index* **untuk fitur Berat Buah (gram)** berdasarkan data terbaru:
#
# ---
#
# ### 1️⃣ **Urutkan data berdasarkan Berat Buah (gram):**
#
# | No | Berat Buah (gram) | Kelas           |
# | -- | ----------------- | --------------- |
# | 4  | 430               | Cucumis sativus |
# | 3  | 480               | Cucumis sativus |
# | 1  | 500               | Cucumis sativus |
# | 12 | 500               | Cucumis sativus |
# | 5  | 510               | Cucumis sativus |
# | 14 | 510               | Cucumis sativus |
# | 2  | 530               | Cucumis sativus |
# | 11 | 550               | Cucumis sativus |
# | 13 | 1600              | Cucumis melo    |
# | 9  | 1750              | Cucumis melo    |
# | 15 | 1800              | Cucumis melo    |
# | 6  | 1800              | Cucumis melo    |
# | 8  | 1850              | Cucumis melo    |
# | 7  | 1900              | Cucumis melo    |
# | 10 | 2000              | Cucumis melo    |
#
# ---
#
# ### 2️⃣ **Ambil threshold split:**
#
# Kita gunakan threshold = **800 gram**
# (sebab semua Cucumis sativus < 800 gram, semua Cucumis melo > 800 gram — terjadi perpindahan mayoritas kelas)
#
# #### Maka:
#
# * **Group Left (≤ 800 gram)** → 8 data (semua Cucumis sativus)
# * **Group Right (> 800 gram)** → 7 data (semua Cucumis melo)
#
# ---
#
# ### 3️⃣ **Komposisi kelas:**
#
# * Sebelum split:
#
#   * 8 *Cucumis sativus*
#   * 7 *Cucumis melo*
#
# $$
# Entropy(D) = -\frac{8}{15} \log_2 \frac{8}{15} - \frac{7}{15} \log_2 \frac{7}{15}
# $$
#
# Sama seperti sebelumnya:
#
# $$
# Entropy(D) \approx 0.994
# $$
#
# ---
#
# ### 4️⃣ **Entropy setelah split:**
#
# #### Group Left (≤ 800 gram):
#
# * 8 *Cucumis sativus*, 0 *Cucumis melo*
#
# $$
# Entropy(left) = -\frac{8}{8}\log_2\frac{8}{8} = 0
# $$
#
# #### Group Right (> 800 gram):
#
# * 7 *Cucumis melo*, 0 *Cucumis sativus*
#
# $$
# Entropy(right) = -\frac{7}{7}\log_2\frac{7}{7} = 0
# $$
#
# ---
#
# ### 5️⃣ **Information Gain:**
#
# $$
# IG = Entropy(D) - \left( \frac{8}{15} \cdot 0 + \frac{7}{15} \cdot 0 \right)
# $$
#
# $$
# IG = 0.994 - 0 = \boxed{0.994}
# $$
#
# ---
#
# ### 6️⃣ **Gini Index**
#
# #### Gini Awal:
#
# $$
# Gini(D) = 1 - \left( \frac{8}{15} \right)^2 - \left( \frac{7}{15} \right)^2
# $$
#
# $$
# Gini(D) \approx 1 - 0.284 - 0.218 \approx 0.498
# $$
#
# #### Gini(Left):
#
# Semua satu kelas → Gini = 0
#
# #### Gini(Right):
#
# Semua satu kelas → Gini = 0
#
# #### Gini Split:
#
# $$
# Gini_{split} = \frac{8}{15} \cdot 0 + \frac{7}{15} \cdot 0 = \boxed{0}
# $$
#
# ---
#
# ### 7️⃣ **Hasil Akhir Fitur "Berat Buah (gram)"**
#
# | Ukuran Evaluasi  | Nilai |
# | ---------------- | ----- |
# | Entropy Awal     | 0.994 |
# | Information Gain | 0.994 |
# | Gini Split       | 0.000 |
#
# ---
#
# ### 🔎 **Kesimpulan**
#
# Fitur Berat Buah (gram) menghasilkan split sempurna, karena seluruh data bisa dipisahkan sempurna dengan threshold 800 gram.
#
# ---

# %% [markdown]
# ## Visualisasi Decision Tree

# %% [markdown]
# Ini adalah code program untuk mencari decision tree sekaligus rules

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.preprocessing import LabelEncoder

# === Data 3 Kelas (Sesuai perhitungan kita sebelumnya) ===
data = {
    "Diameter Buah (cm)": [4.2, 4.5, 4.0, 3.8, 4.3,  # sativus
                          16.0, 17.0, 15.0, 17.5, 14.0, # melo
                          7.0, 7.5, 6.8, 8.0, 7.2],   # metuliferus
    "Berat Buah (gram)": [500, 530, 480, 430, 510,    # sativus
                          1800, 1900, 1750, 2000, 1600, # melo
                          900, 950, 870, 1000, 920],  # metuliferus
    "Kelas": [
        "Cucumis sativus", "Cucumis sativus", "Cucumis sativus", "Cucumis sativus", "Cucumis sativus",
        "Cucumis melo", "Cucumis melo", "Cucumis melo", "Cucumis melo", "Cucumis melo",
        "Cucumis metuliferus", "Cucumis metuliferus", "Cucumis metuliferus", "Cucumis metuliferus", "Cucumis metuliferus"
    ]
}


df = pd.DataFrame(data)

# === Label Encoding ===
le = LabelEncoder()
df['Label'] = le.fit_transform(df['Kelas'])

# Menampilkan hasil encoding agar jelas
print("=== Hasil Label Encoding ===")
for index, nama_kelas in enumerate(le.classes_):
    print(f"{nama_kelas} -> {index}")

# === Fitur dan Target ===
X = df[["Diameter Buah (cm)", "Berat Buah (gram)"]]
y = df["Label"]

# === Train Decision Tree ===
clf = DecisionTreeClassifier(criterion="gini", max_depth=3, random_state=42)
clf.fit(X, y)

# === 1. Tampilkan Pohon Keputusan (Teks) ===
print("\n=== Pohon Keputusan (Decision Tree) ===")
# Menggunakan class_names agar hasilnya menampilkan nama spesies, bukan angka
tree_rules = export_text(clf, 
                         feature_names=list(X.columns), 
                         class_names=le.classes_.tolist())
print(tree_rules)
# Out:
# === Hasil Label Encoding ===
# Cucumis melo -> 0
# Cucumis metuliferus -> 1
# Cucumis sativus -> 2
#
# === Pohon Keputusan (Decision Tree) ===
# |--- Diameter Buah (cm) <= 5.65
# |   |--- class: Cucumis sativus
# |--- Diameter Buah (cm) >  5.65
# |   |--- Berat Buah (gram) <= 1300.00
# |   |   |--- class: Cucumis metuliferus
# |   |--- Berat Buah (gram) >  1300.00
# |   |   |--- class: Cucumis melo

# %% [markdown]
# ## Visualisasi Splitting

# %%
# === Uji 2 Data Baru ===
uji_baru = pd.DataFrame({
    'Diameter Buah (cm)': [5.0, 14.5],
    'Berat Buah (gram)': [600, 1700]
})

prediksi = clf.predict(uji_baru)
hasil = le.inverse_transform(prediksi)

print("\n=== Prediksi 2 Data Baru ===")
for i, (d, b) in enumerate(zip(uji_baru['Diameter Buah (cm)'], uji_baru['Berat Buah (gram)'])):
    print(f"Data {i+1}: Diameter={d}, Berat={b} → Prediksi: {hasil[i]}")

# === Visualisasi Decision Boundary ===
print("\n=== Visualisasi Decision Boundary ===")

# <-- MODIFIKASI 2: Menyediakan 3 warna untuk 3 kelas
plot_colors = "ryb" # r=red, y=yellow, b=blue
plot_step_diameter = 0.1
plot_step_berat = 10

x_min, x_max = X['Diameter Buah (cm)'].min() - 1, X['Diameter Buah (cm)'].max() + 1
y_min, y_max = X['Berat Buah (gram)'].min() - 100, X['Berat Buah (gram)'].max() + 100

xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step_diameter),
                     np.arange(y_min, y_max, plot_step_berat))

grid = np.c_[xx.ravel(), yy.ravel()]
grid_df = pd.DataFrame(grid, columns=['Diameter Buah (cm)', 'Berat Buah (gram)'])
Z = clf.predict(grid_df)
Z = Z.reshape(xx.shape)

plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu, alpha=0.6)

# Plot titik data training
# <-- MODIFIKASI 3: Looping untuk 3 kelas (0, 1, dan 2)
for i, color in zip(range(3), plot_colors):
    idx = np.where(y == i)
    plt.scatter(X.iloc[idx]['Diameter Buah (cm)'], X.iloc[idx]['Berat Buah (gram)'],
                c=color, edgecolor='k', label=le.classes_[i])

plt.xlabel("Diameter Buah (cm)")
plt.ylabel("Berat Buah (gram)")
plt.title("Decision Boundary (Diameter vs Berat Buah)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# === Prediksi 2 Data Baru ===
# Data 1: Diameter=5.0, Berat=600 → Prediksi: Cucumis sativus
# Data 2: Diameter=14.5, Berat=1700 → Prediksi: Cucumis melo
#
# === Visualisasi Decision Boundary ===

# %% [markdown]
# ## Visualisasi Splitting Setelah ada 2 Data Baru

# %%
# === Uji 2 Data Baru ===
uji_baru = pd.DataFrame({
    'Diameter Buah (cm)': [5.0, 14.5],
    'Berat Buah (gram)': [600, 1700]
})

prediksi = clf.predict(uji_baru)
hasil = le.inverse_transform(prediksi)

print("\n=== Prediksi 2 Data Baru ===")
for i, (d, b) in enumerate(zip(uji_baru['Diameter Buah (cm)'], uji_baru['Berat Buah (gram)'])):
    print(f"Data {i+1}: Diameter={d}, Berat={b} → Prediksi: {hasil[i]}")

# === Visualisasi Decision Boundary ===
print("\n=== Visualisasi Decision Boundary ===")

# <-- PERBAIKAN 2: Menyediakan 3 warna untuk 3 kelas
plot_colors = "ryb" # r=red, y=yellow, b=blue
plot_step_diameter = 0.1
plot_step_berat = 10

x_min, x_max = X['Diameter Buah (cm)'].min() - 1, X['Diameter Buah (cm)'].max() + 1
y_min, y_max = X['Berat Buah (gram)'].min() - 100, X['Berat Buah (gram)'].max() + 100

xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step_diameter),
                     np.arange(y_min, y_max, plot_step_berat))

grid = np.c_[xx.ravel(), yy.ravel()]
grid_df = pd.DataFrame(grid, columns=['Diameter Buah (cm)', 'Berat Buah (gram)'])
Z = clf.predict(grid_df)
Z = Z.reshape(xx.shape)

plt.figure(figsize=(10, 8))
plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu, alpha=0.6)

# Plot titik data training
# <-- PERBAIKAN 3: Looping untuk 3 kelas (0, 1, dan 2)
for i, color in zip(range(3), plot_colors):
    idx = np.where(y == i)
    plt.scatter(X.iloc[idx]['Diameter Buah (cm)'], X.iloc[idx]['Berat Buah (gram)'],
                c=color, edgecolor='k', s=60, label=le.classes_[i])

# Plot data uji (Kode ini sudah benar)
plt.scatter(uji_baru['Diameter Buah (cm)'], uji_baru['Berat Buah (gram)'],
            c='black', marker='X', s=200, label='Data Uji')

plt.xlabel("Diameter Buah (cm)")
plt.ylabel("Berat Buah (gram)")
plt.title("Decision Boundary (Diameter vs Berat Buah)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# === Prediksi 2 Data Baru ===
# Data 1: Diameter=5.0, Berat=600 → Prediksi: Cucumis sativus
# Data 2: Diameter=14.5, Berat=1700 → Prediksi: Cucumis melo
#
# === Visualisasi Decision Boundary ===

# %% [markdown]
# ## Visualisasi Decision Tree dalam bentuk gambar

# %%
# === Visualisasi Struktur Pohon ===
print("Menampilkan plot struktur pohon keputusan...")
# <-- MODIFIKASI: Ukuran gambar dibuat lebih seimbang agar mudah dibaca
plt.figure(figsize=(20, 12)) 
plot_tree(
    clf,
    feature_names=["Diameter Buah (cm)", "Berat Buah (gram)"],
    class_names=le.classes_,  # gunakan label string hasil encoding
    filled=True,
    rounded=True,
    impurity=True, # tampilkan nilai Gini
    fontsize=10
)
# <-- MODIFIKASI: Judul disesuaikan untuk 3 kelas
plt.title("Struktur Pohon Keputusan untuk 3 Spesies Cucumis", fontsize=16) 
plt.show()
# Out:
# Menampilkan plot struktur pohon keputusan...

# %% [markdown]
# ## Rules

# %%
# === Ekstrak dan Tampilkan Rules yang Benar dari Model ===
print("=== Rules Pohon Keputusan yang Sebenarnya ===")
tree_rules = export_text(clf, 
                         feature_names=list(X.columns), 
                         class_names=le.classes_.tolist())
print(tree_rules)
# Out:
# === Rules Pohon Keputusan yang Sebenarnya ===
# |--- Diameter Buah (cm) <= 5.65
# |   |--- class: Cucumis sativus
# |--- Diameter Buah (cm) >  5.65
# |   |--- Berat Buah (gram) <= 1300.00
# |   |   |--- class: Cucumis metuliferus
# |   |--- Berat Buah (gram) >  1300.00
# |   |   |--- class: Cucumis melo
